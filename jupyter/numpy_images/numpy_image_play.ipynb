# %%
import numpy as np

# %%
from skimage import io
pic = io.imread('hairyjayn.jpg')
type(pic)
# Out:
# numpy.ndarray

# %%
pic.shape
# Out:
# (400, 400, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(pic)

# %%
plt.imshow(pic[::-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.imshow(pic[::-1])
#
# NameError: name 'plt' is not defined

# %%
plt.imshow(pic[:,::-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plt.imshow(pic[:,::-1])
#
# NameError: name 'plt' is not defined

# %%
plt.imshow(pic[:,:,::-1])

# %%
plt.imshow(pic[50:150,::-1])

# %%
plt.imshow(pic[90:150,90:200,:])

# %%
plt.imshow(pic[::2,::2,:])

# %%
pic_masked = np.where(pic > 130, 255, 0)
plt.imshow(pic_masked)

# %%
plt.imshow(pic[:,:,0].T)
